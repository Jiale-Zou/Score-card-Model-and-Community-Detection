# %% [markdown]
# # Community Detection Algorithm
# Here, we introduce the normal community detection algorithm, including their theory and realization.<br>
# 1. [KL]('KL.ipynb')
# 2. [LPA]('LPA.ipynb')
# 3. [Louvain]('./Louvain.ipynb')
# 4. [Leiden]('./Leiden.ipynb')
# 5. [Infomap]('./Infomap.ipynb')
